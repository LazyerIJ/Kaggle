# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
pd.set_option('max_columns', None)

# %%
df = pd.read_csv('total_df.csv')

# %%
df.head(3)
# Out:
#    back_from_scrimmage  back_oriented_down_field  back_moving_down_field  \
# 0                 3.75                         1                       0
# 1                 4.07                         1                       0
# 2                 3.66                         1                       0
#
#    min_dist   max_dist  mean_dist  std_dist   Dir_sin  diffScoreBeforePlay  \
# 0  1.449724  22.415872   8.046559  4.873845  0.911690                    0
# 1  0.792023  23.025872   8.614623  5.598683  0.740805                    0
# 2  1.646390  20.726285   8.482583  4.642121  0.668612                    0
#
#    PlayerHeight_dense  num_DL  num_BL  num_TE  num_WR   Dis  Orientation  \
# 0                  70       2       2       1       3  0.38       288.02
# 1                  70       2       2       1       3  0.34       239.30
# 2                  70       2       2       1       3  0.60       309.18
#
# ...

# %%
df.corr()['Yards'].sort_values()
# Out:
# back_scrim_away            -0.133465
# YardLine                   -0.092570
# num_TE                     -0.054673
# num_DL                     -0.030873
# num_BL                     -0.030873
# PlayerAge                  -0.028590
# PlayerWeight               -0.027306
# back_oriented_down_field   -0.021729
# Down                       -0.021672
# Orientation                -0.020559
# back_scrim_home            -0.014775
# Rusher_Ori_Dir_Sub         -0.013454
# diffScoreBeforePlay        -0.012502
# Dir_sin                    -0.011402
# DefendersInTheBox          -0.006698
# PlayerHeight_dense         -0.006587
# back_from_scrimmage         0.000852
# RusherY                     0.002796
# Dir                         0.006028
# radian_std                  0.007940
# Position                    0.008291
# min_dist                    0.026056
# back_moving_down_field      0.031522
# v_vertical                  0.039142
# v_horizontal                0.042924
# ...

# %%
tmp = {'ACE': 4.0,
                     'EMPTY': 5.04347826,
                     'I_FORM': 4.02240199,
                     'JUMBO': 1.756238,
                     'PISTOL': 4.29836066,
                     'SHOTGUN': 4.50816089,
                     'SINGLEBACK': 4.22211379,
                     'WILDCAT': 4.22222222,
                     'unknown': 2.8}
sorted(tmp.items(), key=lambda x: x[1])
# Out:
# [('JUMBO', 1.756238),
#  ('unknown', 2.8),
#  ('ACE', 4.0),
#  ('I_FORM', 4.02240199),
#  ('SINGLEBACK', 4.22211379),
#  ('WILDCAT', 4.22222222),
#  ('PISTOL', 4.29836066),
#  ('SHOTGUN', 4.50816089),
#  ('EMPTY', 5.04347826)]
